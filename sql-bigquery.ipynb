# %%
from google.cloud import bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "credentials/endless-beach-228506-b15de187c224.json"

# %%
# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "world_bank_intl_education" dataset
dataset_ref = client.dataset("world_bank_intl_education", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# Construct a reference to the "international_education" table
table_ref = dataset_ref.table("international_education")

# API request - fetch the table
table = client.get_table(table_ref)

# Preview the first five lines of the "international_education" table
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#   country_name country_code  \
# 0      Nigeria          NGA
# 1     Pakistan          PAK
# 2        Palau          PLW
# 3        Palau          PLW
# 4   Mauritania          MRT
#
#                                       indicator_name     indicator_code  \
# 0  Population of the official age for the last gr...     SP.PRM.GRAD.FE
# 1      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 2  Gross enrolment ratio, primary, gender parity ...  SE.ENR.PRIM.FM.ZS
# 3  Teachers in secondary education, both sexes (n...        SE.SEC.TCHR
# 4  Enrolment in tertiary education, all programme...     SE.TER.ENRL.FE
#
#           value  year
# 0  2.273274e+06  2016
# 1  5.245642e+03  2016
# 2  9.868000e-01  2016
# 3  7.200000e+01  2016
# 4  6.678000e+03  2016
